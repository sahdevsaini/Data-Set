04,12277.56,19571.16,14100.96,20178.96,23096.4,18963.36,3889.92,18598.68,12277.56,8873.88,15681.24,17504.64,16167.48,18112.44,21880.8,14465.64,14465.64,9724.8,14830.32,20786.76,18234.0,10211.04,17626.2,9238.56,14222.52,13979.4,32821.2,24555.12,14222.52,14344.08,15316.56,12763.8,14830.32,10575.72,31848.72,21394.56,27472.56,12520.68,21029.88,19328.04,8144.52,13128.48,12034.44,7172.04,23825.76,21029.88,9238.56,11791.32,15559.68,30997.8,16289.04],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar" ...

# %%
y = df['Sales']

# %%
X = df.drop(columns=['Sales'])

# %%
X
# Out:
#      youtube    SEO  Social Media
# 0     847.20  19.20         48.96
# 1     351.48  33.96         51.84
# 2     135.48  20.88         46.32
# 3     116.64   1.80         36.00
# 4     318.72  24.00          0.36
# ..       ...    ...           ...
# 166    45.84   4.44         16.56
# 167   113.04   5.88          9.72
# 168   212.40  11.16          7.68
# 169   340.32  50.40         79.44
# 170   278.52  10.32         10.44
#
# [171 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Initialize model_scores dictionary
model_scores = {}

# Train and evaluate each model
for name, model in models.items():
    model.fit(X_train, y_train)  # Train the model
    y_pred = model.predict(X_test)  # Make predictions

    # Evaluate using MSE and R²
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Store scores in dictionary
    model_scores[name] = {"MSE": mse, "R²": r2}

    print(f"{name}: MSE = {mse:.4f}, R² = {r2:.4f}")

# Find the best model based on R²
best_model_name = max(model_scores, key=lambda x: model_scores[x]["R²"])
best_model_r2 = model_scores[best_model_name]["R²"]

print("\nBest Model:")
print(f"{best_model_name}: R² = {best_model_r2:.4f}")
# Out:
# Linear Regression: MSE = 3804871.4771, R² = 0.8743
# Decision Tree: MSE = 1938298.3731, R² = 0.9359
# Random Forest: MSE = 1264216.1663, R² = 0.9582
# SVR: MSE = 44581635.5616, R² = -0.4733
# KNN: MSE = 5270111.2620, R² = 0.8258
#
# Best Model:
# Random Forest: R² = 0.9582

# %%
model.coef_
# Out:
# array([ 34.61224598, 190.85614373,  10.66216902])

# %%
model.intercept_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-925cf82d3ca8> in <cell line: 1>()
# ----> 1 model.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 36380987.1262471

# %%
df  = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})

# %%
df
# Out:
#        Actual     Predicted
# 135  14465.64  13360.206544
# 110  25162.92  23688.842156
# 89   19328.04  19072.879581
# 24   25770.72  24275.186130
# 159  19328.04  22634.358584
# 59   15681.24  14400.403536
# 108  25284.48  25504.608042
# 0    12763.80  46771.747317
# 100  11791.32   9658.829637
# 155  21394.56  22581.277364
# 164  23825.76  22255.125353
# 143   9238.56   9142.212483
# 14   15681.24  17047.769898
# 7    30876.24  28273.218335
# 169  30997.80  29019.645746
# 134  21880.80  20917.464935
# 139  20786.76  21041.694783
# 161  13128.48  14927.166406
# 29   28931.28  26544.410649
# 52   14951.88  17964.006094
# 49    6442.68  10517.367038
# 13   25162.92  26148.071820
# 51   14344.08  13823.773071
# 160   8144.52   7320.285013
# 61   13614.72  12134.617488
# 47    8387.64   5449.502496
# 25   24555.12  24712.454904
# 60   20300.52  20528.729748
# 2    14465.64  13840.869324
# 18   28201.92  26291.652488
# 120  12277.56  11839.554084
# 73   17990.88  21519.177902
# 98   10697.28   8003.764953
# 35   21880.80  20522.445603
# 20   11791.32   9978.599023

# %%
r2_score = r2_score(y_test,y_pred)
r2_score
# Out:
# 0.20353292721407445
